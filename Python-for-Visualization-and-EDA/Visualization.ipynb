# %%
import pandas as pd
import seaborn as sns   # Why sns?  It's a reference to The West Wing
import matplotlib.pyplot as plt  # seaborn is based on matplotlib
sns.set(color_codes=True) # adds a nice background to the graphs
# %matplotlib inline 
# tells python to actually display the graphs

# %%
auto = pd.read_csv('Automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Plotting univariate distributions
#
# The most convenient way to take a quick look at a univariate distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE).

# %%
sns.distplot(auto['highway_mpg']);
# Out:
# /Users/Jesus/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# we can turn the kde off and put a tic mark along the x-axis for every data point with rug
sns.distplot(auto['city_mpg'], kde=False, rug=True);
# Out:
# /Users/Jesus/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/Jesus/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Plotting bivariate distributions
#
# It can also be useful to visualize a relationship between two variables. The easiest way to do this in seaborn is to use the jointplot() function, which creates a scatterplot of the two variables along with the histograms of each next to the appropriate axes.

# %%
sns.jointplot(x = auto['engine_size'], y = auto['horsepower']);

# %% [markdown]
# ### Hex Bin Plots
#
# We can make a hex bin plot that breaks the 2D area into hexagons and the number of points in each hexagon determines the color

# %%
sns.jointplot(x = auto['engine_size'], y = auto['horsepower'], kind="hex");

# %% [markdown]
# ### Kernel Density Estimation
#
# We can make a 2D estimation of the density also

# %%
sns.jointplot(x = auto['engine_size'], y = auto['horsepower'], kind="kde");

# %% [markdown]
# ## Visualizing pairwise relationships in a dataset
#
# To plot multiple pairwise scatterplots in a dataset, you can use the pairplot() function. This creates a matrix of axes and shows the relationship for each pair of columns in a DataFrame, it also draws the histogram of each variable on the diagonal Axes:
#
# Be careful about toggle scrolling in the cell menu!!!

# %%
sns.pairplot(auto[['normalized_losses', 'engine_size', 'horsepower']]);

# %% [markdown]
# ## 3.2 Test Your Understanding

# %%
# seaborn is based on matplotlib
# TRUE

# %%
# sns.set(color_codes=True) helps add different _____ to the graphs
# Backgrounds

# %%
# seaborn.distplot() is used basically for a univariate set of observations and visualizes it through a histogram i.e. only one variable and hence we choose one particular column of the dataset.
# TRUE

# %%
# Which of the following is/are true about seaborn.jointplot():

# A. It is used to draw a plot of two variables with bivariate and univariate graphs.
# B. It basically combines two different plots.
# C. The default parameter for kind of plot is scatter.
# D. The kind of plot can also be hex or kde.

# A,B,C,D

# %%
# The most convenient way to take a quick look at a univariate distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE).
# TRUE

# %%
# Which of the following statement(s) is/are correct w.r.t seaborn.pairplot():
    
# A. By default, this function will create a grid of Axes such that each numeric variable in data will be shared in the y-axis across a single row and in the x-axis across a single column.
# B. The diagonal Axes are treated differently, drawing a plot to show the univariate distribution of the data for the variable in that column.

# Both A and B

# %% [markdown]
# ## Plotting with categorical data

# %% [markdown]
# In a strip plot, the scatterplot points will usually overlap. This makes it difficult to see the full distribution of data. One easy solution is to adjust the positions (only along the categorical axis) using “jitter"

# %%
sns.stripplot(x = auto['fuel_type'], y = auto['horsepower'], jitter=True);

# %% [markdown]
# A different approach would be to use the function swarmplot(), which positions each scatterplot point on the categorical axis and avoids overlapping points:

# %%
sns.swarmplot(x = auto['fuel_type'], y = auto['horsepower']);
# Out:
# /Users/Jesus/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Boxplots
#
# Another common graph is a boxplot(). This kind of plot shows the three quartile values of the distribution along with extreme values. The “whiskers” extend to points that lie within 1.5 IQRs of the lower and upper quartile, and then observations that fall outside this range are displayed independently.

# %%
sns.boxplot(x = auto['number_of_doors'], y = auto['horsepower']);

# Two-door cars

# 1st Quartile - 25% of two door cars have less than 75 hp

# Median line - 50% of two door cars have more than 100 hp
# Median line - 50% of two door cars have less than 100 hp

# 3rd Quartile - 25% of two door cars have more than 130 hp
# 3rd Quartile - 75% of two door cars have less than 130 hp

# Right-skewed distribution 


# Four-door cars

# 1st Quartile - 25% of four door cars have less than 75 hp

# Median line - 50% of four door cars have more than 90 hp
# Median line - 50% of four door cars have less than 90 hp

# 3rd Quartile - 25% of four door cars have more than 110 hp
# 3rd Quartile - 75% of four door cars have less than 110 hp

# Right-skewed distribution 


# Whisker denotes the range(min, max) for which a data point can lie in
# Any data point outside the range is considere an outlier

# %%
sns.boxplot(x = auto['number_of_doors'], y = auto['horsepower'], hue=auto['fuel_type']);

# %% [markdown]
# ## Bar plots
#
# We can plot the mean of a a dataset, separated in categories using the barplot() function. When there are multiple observations in each category, it uses bootstrapping to compute a confidence interval around the estimate and plots that using error bars:
#
# Bar plots start at 0, which can sometimes be practical if zero is a number you want to compare to

# %%
sns.barplot(x = auto['body_style'], y = auto['horsepower'], hue=auto['fuel_type']);

# the bar chart represents the mean of hp
# the line represented a 95% confidence interval

# %% [markdown]
# A special case for the bar plot is when you want to show the number of observations in each category rather than computing the mean of a second variable. This is similar to a histogram over a categorical, rather than quantitative, variable. In seaborn, it’s easy to do so with the countplot() function:

# %%
sns.countplot(x = auto['body_style']);

# %%
sns.countplot(x = auto['body_style'],hue=auto['fuel_type']);

# %% [markdown]
# ## Point plots
#
# An alternative style for visualizing the same information is offered by the pointplot() function. This function also encodes the value of the estimate with height on the other axis, but rather than show a full bar it just plots the point estimate and confidence interval. Additionally, pointplot connects points from the same hue category. This makes it easy to see how the main relationship is changing as a function of a second variable, because your eyes are quite good at picking up on differences of slopes:

# %%
sns.pointplot(x = auto['body_style'], y = auto['horsepower'], hue=auto['number_of_doors']);

# Point plot represents what is the actually value of the mean(average hp)

# %% [markdown]
# ## Drawing multi-panel categorical plots

# %%
sns.catplot(x="fuel_type",
               y = "horsepower",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=auto, 
               kind="box");

# %%
sns.catplot(x="fuel_type",
               y = "horsepower",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=auto, 
               kind="violin");

# %%
sns.catplot(x="fuel_type",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=auto, 
               kind="count");

# %% [markdown]
# Various types of kind input : {``point``, ``bar``, ``count``, ``box``, ``violin``, ``strip``}

# %% [markdown]
# ## Function to draw linear regression models
#
# lmplot() is one of the most widely used function to quickly plot the Linear Relationship between 2 variables

# %%
sns.lmplot(y = "horsepower", x = "engine_size", data=auto);

# %%
sns.lmplot(y = "horsepower", x = "engine_size",hue="fuel_type", data=auto);

# %% [markdown]
# ## 3.3 Test Your Understanding

# %%
# Which of the following can be used to visualize the data in Python?

# A. seaborn.stripplot()
# B. seaborn.swarmplot()
# C. seaborn.boxplot()
# D. seaborn.catplot()

# A,B,C,D

# %%
# _____ helps us see the full distribution of data when scatterplot points might overlap.

# 1.jitters
# 2.swarm plot

# Both 1 and 2

# %%
# Which of the following is correct about seaborn.boxplot()?

# All of the above are correct.

# %%
# Choose the correct choices regarding the following in Seaborn library in Python:

# A. A barplot is basically used to aggregate the categorical data according to some methods and by default its the mean.
# B. A countplot basically counts the categories and returns a count of their occurrences.
# C. A violinplot is similar to the boxplot except that it provides a higher, more advanced visualization and uses the kernel density estimation to give a better description of the data distribution.
# D. Swarmplot is very similar to the stripplot except for the fact that the points are adjusted so that they do not overlap.

# A,B,C,D

# %%
# The seaborn.catplot() function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations.
# The kind parameter selects the underlying axes-level function to use:

# A. kind='bar'
# B. kind='count'
# C. kind='violin'
# D. kind='strip'

# A,B,C,D
